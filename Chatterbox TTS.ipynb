# %% [markdown]
# # Chatterbox TTS on Google Colab
#
# This notebook allows you to run the Chatterbox TTS application directly on Google Colab, using a GPU for faster performance.

# %% [markdown]
# ### Step 1: Check Python Version
#
# Let's verify the Python version in the Colab environment. This project is tested with Python 3.10 and newer.

# %%
# !python --version

# %% [markdown]
# ### Step 2: Clone the GitHub Repository
#
# First, we clone the project from the specified GitHub repository.

# %%
# !git clone https://github.com/airdropia/Chatterbox-TTS.git

# %% [markdown]
# ### Step 3: Navigate to the Project Directory
#
# Now, we move into the cloned project's directory.

# %%
# %cd Chatterbox-TTS

# %% [markdown]
# ### Step 4: Install Dependencies
#
# Next, we install all the required libraries from the `requirements.txt` file. We also install `s3tokenizer` from a specific commit to ensure compatibility, and `pyngrok` as a fallback for sharing the Gradio app.

# %%
# !pip install git+https://github.com/step-audio/s3tokenizer.git@88f2263 --quiet
# !pip install -r requirements.txt --quiet
# !pip install pyngrok --quiet

# %% [markdown]
# ### Step 5: Run the Application
#
# Finally, we launch the Gradio application. A public URL will be generated, which you can use to access the app in your browser.

# %%
# !python app.py
